# %% [markdown]
# <a href="https://colab.research.google.com/github/JoacoL35/Progra/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1) División entera (`//`)
# División entre dos numeros en donde el resultado simpre se redondeara al numero entero menor
#
# ---
# 2) Expresión
# una colección de operadores y números.
#
# ---
# 3) Valor
# es el resultado de una expresión
#
# ---
#
# 4) Error: SyntaxError
# Ocurre cuando llamo una funcion y cometo un error en su escritura
